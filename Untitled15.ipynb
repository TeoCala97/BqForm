# %% [markdown]
# <a href="https://colab.research.google.com/github/TeoCala97/BqForm/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/TeoCala97/Form_app.git
# Out:
# Cloning into 'Form_app'...
# remote: Enumerating objects: 3286, done.
# remote: Counting objects: 100% (3286/3286), done.
# remote: Compressing objects: 100% (2418/2418), done.
# remote: Total 3286 (delta 980), reused 2958 (delta 652), pack-reused 0
# Receiving objects: 100% (3286/3286), 16.35 MiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (980/980), done.

# %%
# %cd Form_app/
# Out:
# /content/Form_app

# %%
! git checkout 001/static_2
# Out:
# Branch '001/static_2' set up to track remote branch '001/static_2' from 'origin'.
# Switched to a new branch '001/static_2'

# %%
! git pull
# Out:
# Already up to date.

# %%
! pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://storage.googleapis.com/soditools/soditools-1.0.4-py3-none-any.whl (6.2 kB)
# ...
#   Using cached aiohttp-3.8.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
# ...
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# ...
#   Using cached asgiref-3.5.2-py3-none-any.whl (22 kB)
# ...
#   Using cached astroid-2.11.5-py3-none-any.whl (250 kB)
# ...
#   Using cached asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#   Using cached atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# ...
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# ...
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# ...
#   Using cached bleach-5.0.0-py3-none-any.whl (160 kB)
# ...
#   Using cached cachetools-4.2.4-py3-none-any.whl (10 kB)
# ...

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://rik4azrwps-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
! pip install django
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 64.5 MB/s eta 0:00:00
# ...

# %%
! python manage.py runserver 8000
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# April 03, 2023 - 23:22:06
# Django version 4.0.5, using settings 'Form_App.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [03/Apr/2023 23:22:09] "GET / HTTP/1.1" 200 21342
# [03/Apr/2023 23:22:09] "GET /static/core/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 200 144877
# [03/Apr/2023 23:22:09] "GET /static/core/core/css/main.css HTTP/1.1" 404 1836
# [03/Apr/2023 23:22:09] "GET /static/core/vendor/font-awesome/css/font-awesome.min.css HTTP/1.1" 200 31000
# [03/Apr/2023 23:22:10] "GET /static/vendor/jquery/jquery.min.js HTTP/1.1" 404 1851
# [03/Apr/2023 23:22:10] "GET /static/core/img/sodimac.png HTTP/1.1" 200 56013
# [03/Apr/2023 23:22:10] "GET /static/js/main.js HTTP/1.1" 404 1800
# [03/Apr/2023 23:22:10] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 404 1899
# ...
